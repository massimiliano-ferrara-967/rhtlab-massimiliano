# %% [markdown]
# # First test file

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Example comment

# %% [markdown]
# # Example comment 2

# %%
import pyomo.environ as pyo

# %%
import os

print(os.getcwd())

msg = "Hello Jupyter World"
print(msg)

# %%
b=0;
a=b

# %%
# Example of shell commands
# !pwd
# %pwd

# %%
1+2

# %%
c = 2;
a = 1;

# %% [markdown]
# # Title level 1
# ## Title level 2
# ### Title level 3
# #### Title level 4

# %% [markdown]
# Examples of lists
#
# Ordered list:
#
# 1. Step 1
#     2. Step 1B
# 3. Step 2
#
# Unordered list
#
# * learning rate
# * cycle length
# * weight decay
#
# Task list
#
# - [x] Learn Jupyter Notebooks
#     - [x] Writing
#     - [x] Modes
#     - [x] Other Considerations
# - [ ] Change the world

# %%
# Plotting example
# %matplotlib inline
import matplotlib.pyplot as plt
a = 1
b = a + 1
c = a + b + 1
d = a + b + c + 1
a, b, c, d

plt.plot([a, b, c ,d])
plt.show()    # plt.show() is not necessary in Jupyter notebooks, but it is in standard Python scripts

# %%
#?plt.plot
# ?print

# %%
# %timeit [i+1 for i in range(10000)]
# Out:
# 146 μs ± 721 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)
