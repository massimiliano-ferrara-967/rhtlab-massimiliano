# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Example comment

# %% [markdown]
# # Example comment 2

# %%
import pyomo.environ as pyo

# %%
b=0;
a=b

# %%
1+2

# %%
import os

print(os.getcwd())

msg = "Hello Jupyter World"
print(msg)
