# %% [markdown]
# This small script shows some basic commands to create an excel file from a DataFrame object. Then, it shows how to read from such an excel file.

# %%
import pandas as pd

a = [1, 2, 3, 4, 5]
b = [6, 8, 4, 1, 2]
c = [2, 4, 6, 8, 10]

# df_test = pd.DataFrame([a, b, c], index=None, columns=['A', 'B', 'C', 'D', 'E'])
df_test = pd.DataFrame([a, b, c], index=["PV", "EL", "Load"], columns=['A', 'B', 'C', 'D', 'E'])

# df_test.to_excel("test.xlsx", index=True, header=True)

print(df_test)

df_test_read = pd.read_excel("test.xlsx", index_col=0)

print(df_test_read)

Ppv = df_test_read.loc["PV"].tolist()
vert_column = df_test_read['A'].tolist()

print(Ppv)
print(vert_column)
# Out:
#       A  B  C  D   E
# PV    1  2  3  4   5
# EL    6  8  4  1   2
# Load  2  4  6  8  10
#       A  B  C  D   E
# PV    1  2  3  4   5
# EL    6  8  4  1   2
# Load  2  4  6  8  10
# [1, 2, 3, 4, 5]
# [1, 6, 2]

# %%
# Example creation of a list of multiple elements with the same value
[25] * 4
# Out:
# [25, 25, 25, 25]
